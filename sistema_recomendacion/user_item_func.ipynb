# %% [markdown]
# En este archivo voy a desarrollar los prototipos necesarios que me permitan desplegar el sistema de recomendación user-item based, tanto en local cómo en Render.

# %% [markdown]
# Primer prototipo (voy a copiar y pegar todo el código previamente creado, para a continuación borrar las partes innecesarias)

# %%
# Para procesar los datos
import pandas as pd
import numpy as np
import scipy.stats as stats

# Para visualizar los datos
import seaborn as sns

# Para la similitud
from sklearn.metrics.pairwise import cosine_similarity

juegos = pd.read_parquet("../Datasets/steam_games_complete.parquet")
reseñas = pd.read_parquet("../Datasets/reviews_con_puntaje.parquet")

juegos_con_mas_de_100_reseñas = reseñas["item_id"].value_counts() > 100 # 99 juegos con más de 100 reseñas

# Lista que me va a servir para eliminar los juegos que no tengan más de 100 reseñas
lista_booleana_para_mascara = []
for id in reseñas["item_id"]: # Por cada id en la columna de item_id de las reseñas,
    lista_booleana_para_mascara.append(juegos_con_mas_de_100_reseñas[id]) # Se agrega el valor correspondiente a la lista booleana, si tiene más de 100 reseñas, se agrega True, sino, false. Esto lo hago porque la variable "juegos_con_mas_de_100_reseñas" sólo tiene en cuenta valores únicos, y para aplicar una mascara, yo necesito saber en cada fila si corresponde con True o False

reseñas = reseñas[lista_booleana_para_mascara] # Aplico la mascara previamente creada

usuarios_con_mas_de_5_reseñas = reseñas["user_id"].value_counts() > 5 # Creo una variable que almacene con True los usuarios que hicieron más de 5 reseñas, y con False los que hicieron 5 reseñas o menos.

# Aplico el mismo procedimiento que con los juegos
lista_booleana_para_mascara = []
for id in reseñas["user_id"]:
    lista_booleana_para_mascara.append(usuarios_con_mas_de_5_reseñas[id])

reseñas = reseñas[lista_booleana_para_mascara] # Aplico la máscara para dejar unicamente a los usuarios con más de 5 reseñas

reseñas["puntaje_aumentado"] =  reseñas["puntaje"] + 1 # Lo que voy a hacer es aumentar el valor del puntaje de las reseñas en 1, considerando las negativas con un 1, las neutras con un 2 y las positivas con un 3.

print(len(reseñas["item_id"].unique())) # 99 juegos
print(len(reseñas["user_id"].unique())) # 456 usuarios

juegos_y_reseñas = pd.merge(reseñas,juegos,on="item_id") # Con esto lo que busco hacer es unir las tablas tanto de juegos cómo la de reseñas, porque en la de reseñas no tengo el nombre del juego, y es un valor útil.

# A continuación, elimino con un bucle las columnas innecesarias
for columna in juegos_y_reseñas.columns:
    if columna not in ["user_id","puntaje_aumentado","item_name"]:
        juegos_y_reseñas.drop(columna, inplace=True, axis=1)
print(juegos_y_reseñas.columns)

# Creo una nueva tabla que cómo nombre de columnas va a tener el nombre de los juegos, cómo indice de las filas va a tener el ID de cada usuario y cómo valores va a tener el puntaje
matrix = juegos_y_reseñas.pivot_table(index='user_id',columns='item_name',values='puntaje_aumentado')

# Normalizo la tabla previamente creada restandole la media de cada fila a la fila correspondiente.
matrix_norm = matrix.subtract(matrix.mean(axis=1), axis = 'rows')

# Rellenar NaN con 0s ya que el coseno no se ve afectado por ceros
matrix_norm_filled = matrix_norm.fillna(0)

# Calcular la similitud del coseno
similitud_del_coseno = cosine_similarity(matrix_norm_filled)

similitud_de_usuarios_coseno = pd.DataFrame(similitud_del_coseno, index=matrix_norm.index, columns=matrix_norm.index)
# Out:
# 99
# 456
# Index(['user_id', 'puntaje_aumentado', 'item_name'], dtype='object')

# %% [markdown]
# Bueno, teniendo en consideración todo lo que acabo de hacer, las tablas que necesito son:
#
# - similitud_de_usuarios_coseno
# - matrix_norm
#
# Asi que procedo a exportar en formato parquet las tablas correspondientes a esas variables para poderme manejar de forma más cómoda en la función

# %%
similitud_de_usuarios_coseno.to_parquet("../Datasets/recomendacion/similitud_entre_usuarios.parquet",compression="snappy")
similitud_de_usuarios_coseno
# Out:
# user_id                    09879655452567  10051997   1011001  \
# user_id
# 09879655452567                   1.000000  0.000000  0.000000
# 10051997                         0.000000  1.000000 -0.154746
# 1011001                          0.000000 -0.154746  1.000000
# 111222333444555666888            0.000000 -0.333333  0.154746
# 1234567io9872345678765432        0.000000 -0.730297  0.355983
# ...                                   ...       ...       ...
# zakbot                          -0.167705  0.000000  0.000000
# zayyntt                          0.000000 -0.091287 -0.084758
# zerzang                          0.000000  0.000000  0.000000
# zrustz16                         0.000000 -0.596285  0.207614
# zyr0n1c                          0.000000  0.000000  0.000000
#
# user_id                    111222333444555666888  1234567io9872345678765432  \
# user_id
# 09879655452567                          0.000000                   0.000000
# 10051997                               -0.333333                  -0.730297
# 1011001                                 0.154746                   0.355983
# 111222333444555666888                   1.000000                   0.365148
# 1234567io9872345678765432               0.365148                   1.000000
# ...                                          ...                        ...
# zakbot                                  0.000000                   0.000000
# zayyntt                                 0.000000                   0.050000
# zerzang                                 0.000000                   0.000000
# zrustz16                                0.223607                   0.571548
# zyr0n1c                                 0.000000                   0.000000
#
# user_id                    1873410337     1snap    210396     29123      2sBs  \
# user_id
# 09879655452567               0.111803  0.265334  0.000000  0.000000  0.000000
# 10051997                     0.821584  0.000000  0.117851  0.288675  0.484481
# 1011001                     -0.339032  0.000000  0.109422  0.268028 -0.034602
# 111222333444555666888       -0.365148  0.000000  0.000000  0.000000 -0.186339
# 1234567io9872345678765432   -0.800000  0.000000  0.000000  0.000000 -0.306186
# ...                               ...       ...       ...       ...       ...
# zakbot                      -0.075000  0.000000  0.000000  0.000000  0.000000
# zayyntt                      0.000000  0.339032 -0.064550 -0.158114  0.183712
# zerzang                      0.000000  0.000000  0.000000  0.000000  0.000000
# zrustz16                    -0.571548  0.000000  0.000000  0.000000 -0.250000
# zyr0n1c                      0.000000  0.000000  0.000000  0.000000  0.000000
#
# user_id                    ...  xtomx_freedom    yotuic  you_re_ded  \
# user_id                    ...
# 09879655452567             ...       0.000000  0.000000    0.000000
# 10051997                   ...       0.521749 -0.125988    0.195180
# 1011001                    ...       0.069205  0.058489    0.181220
# 111222333444555666888      ...      -0.149071  0.062994    0.000000
# 1234567io9872345678765432  ...      -0.244949  0.345033   -0.106904
# ...                        ...            ...       ...         ...
# zakbot                     ...       0.000000  0.000000    0.000000
# zayyntt                    ...      -0.122474  0.207020   -0.213809
# zerzang                    ...       0.000000  0.000000    0.000000
# zrustz16                   ...      -0.200000  0.422577   -0.174574
# zyr0n1c                    ...       0.000000  0.000000    0.000000
#
# user_id                    youngbenaffleck   zaaikbr    zakbot   zayyntt  \
# user_id
# 09879655452567                    0.000000  0.000000 -0.167705  0.000000
# 10051997                          0.182574  0.000000  0.000000 -0.091287
# 1011001                          -0.288177  0.346023  0.000000 -0.084758
# 111222333444555666888            -0.091287  0.000000  0.000000  0.000000
# 1234567io9872345678765432        -0.275000  0.000000  0.000000  0.050000
# ...                                    ...       ...       ...       ...
# zakbot                            0.262500  0.000000  1.000000  0.000000
# zayyntt                           0.000000 -0.163299  0.000000  1.000000
# zerzang                           0.000000  0.000000  0.000000  0.000000
# zrustz16                         -0.122474  0.000000  0.000000  0.081650
# zyr0n1c                           0.000000  0.000000  0.000000  0.000000
#
# user_id                    zerzang  zrustz16  zyr0n1c
# user_id
# 09879655452567                 0.0  0.000000      0.0
# 10051997                       0.0 -0.596285      0.0
# 1011001                        0.0  0.207614      0.0
# 111222333444555666888          0.0  0.223607      0.0
# 1234567io9872345678765432      0.0  0.571548      0.0
# ...                            ...       ...      ...
# zakbot                         0.0  0.000000      0.0
# zayyntt                        0.0  0.081650      0.0
# zerzang                        0.0  0.000000      0.0
# zrustz16                       0.0  1.000000      0.0
# zyr0n1c                        0.0  0.000000      0.0
#
# [456 rows x 456 columns]

# %%
matrix_norm.to_parquet("../Datasets/recomendacion/matriz_normalizada.parquet",compression="snappy")
matrix_norm
# Out:
# item_name                  APB Reloaded  ARK: Survival Evolved  \
# user_id
# 09879655452567                      NaN                    1.0
# 10051997                            NaN                    NaN
# 1011001                             NaN                    NaN
# 111222333444555666888               NaN                    NaN
# 1234567io9872345678765432          -0.2                    NaN
# ...                                 ...                    ...
# zakbot                              NaN                   -0.6
# zayyntt                             NaN                    NaN
# zerzang                             NaN                    NaN
# zrustz16                            NaN                    NaN
# zyr0n1c                             NaN                    NaN
#
# item_name                  Ace of Spades: Battle Builder  \
# user_id
# 09879655452567                                       NaN
# 10051997                                             NaN
# 1011001                                              NaN
# 111222333444555666888                                NaN
# 1234567io9872345678765432                            NaN
# ...                                                  ...
# zakbot                                              -0.6
# zayyntt                                              NaN
# zerzang                                              NaN
# zrustz16                                             NaN
# zyr0n1c                                              NaN
#
# item_name                  AdVenture Capitalist  Arma 3  \
# user_id
# 09879655452567                              NaN     NaN
# 10051997                                    NaN     NaN
# 1011001                                     NaN     NaN
# 111222333444555666888                       NaN     NaN
# 1234567io9872345678765432                   NaN    -0.2
# ...                                         ...     ...
# zakbot                                      NaN     NaN
# zayyntt                                     NaN     NaN
# zerzang                                     NaN     NaN
# zrustz16                                    NaN     NaN
# zyr0n1c                                     NaN     NaN
#
# item_name                  Awesomenauts - the 2D moba  \
# user_id
# 09879655452567                                    NaN
# 10051997                                          NaN
# 1011001                                           NaN
# 111222333444555666888                             NaN
# 1234567io9872345678765432                         NaN
# ...                                               ...
# zakbot                                            NaN
# zayyntt                                           NaN
# zerzang                                           NaN
# zrustz16                                          NaN
# zyr0n1c                                           NaN
#
# item_name                  Bad Rats: the Rats' Revenge  BattleBlock Theater®  \
# user_id
# 09879655452567                                     NaN                   NaN
# 10051997                                           NaN                   NaN
# 1011001                                            NaN                   NaN
# 111222333444555666888                              NaN             -0.666667
# 1234567io9872345678765432                          NaN                   NaN
# ...                                                ...                   ...
# zakbot                                             NaN                   NaN
# zayyntt                                            NaN                   NaN
# zerzang                                            NaN                   NaN
# zrustz16                                           NaN                   NaN
# zyr0n1c                                            NaN                   NaN
#
# item_name                  BioShock Infinite  Blacklight: Retribution  ...  \
# user_id                                                                ...
# 09879655452567                           NaN                      NaN  ...
# 10051997                                 NaN                      NaN  ...
# 1011001                                  NaN                      NaN  ...
# 111222333444555666888               0.333333                      NaN  ...
# 1234567io9872345678765432                NaN                      NaN  ...
# ...                                      ...                      ...  ...
# zakbot                                   NaN                      NaN  ...
# zayyntt                                  NaN                      NaN  ...
# zerzang                                  NaN                      NaN  ...
# zrustz16                                 NaN                      NaN  ...
# zyr0n1c                                  NaN                      NaN  ...
#
# item_name                  The Stanley Parable  The Walking Dead  \
# user_id
# 09879655452567                             NaN               NaN
# 10051997                                   NaN               NaN
# 1011001                                    NaN               NaN
# 111222333444555666888                      NaN               NaN
# 1234567io9872345678765432                  NaN               NaN
# ...                                        ...               ...
# zakbot                                     NaN               NaN
# zayyntt                                    NaN               NaN
# zerzang                                    NaN               NaN
# zrustz16                                   NaN               NaN
# zyr0n1c                                    NaN               NaN
#
# item_name                  The Walking Dead: Season 2  Tomb Raider  Trove  \
# user_id
# 09879655452567                                    NaN          NaN   -1.0
# 10051997                                          NaN          NaN    NaN
# 1011001                                           NaN          NaN    NaN
# 111222333444555666888                             NaN          NaN    NaN
# 1234567io9872345678765432                         NaN          NaN    NaN
# ...                                               ...          ...    ...
# zakbot                                            NaN          NaN    NaN
# zayyntt                                           NaN          NaN    NaN
# zerzang                                           NaN          NaN    NaN
# zrustz16                                          NaN          NaN    NaN
# zyr0n1c                                           NaN          NaN    NaN
#
# item_name                  Undertale  Unturned  Verdun  Warframe  \
# user_id
# 09879655452567                   NaN       NaN     NaN       NaN
# 10051997                         NaN       NaN     NaN       NaN
# 1011001                          NaN       NaN     NaN       NaN
# 111222333444555666888            NaN       NaN     NaN       NaN
# 1234567io9872345678765432        NaN      -0.2     NaN       NaN
# ...                              ...       ...     ...       ...
# zakbot                           NaN       NaN     NaN       NaN
# zayyntt                          NaN      -0.2     NaN       NaN
# zerzang                          NaN       NaN     NaN       NaN
# zrustz16                         NaN      -0.4     NaN       NaN
# zyr0n1c                          NaN       NaN     NaN       0.0
#
# item_name                  XCOM: Enemy Unknown
# user_id
# 09879655452567                             NaN
# 10051997                                   NaN
# 1011001                                    NaN
# 111222333444555666888                      NaN
# 1234567io9872345678765432                  NaN
# ...                                        ...
# zakbot                                     NaN
# zayyntt                                    NaN
# zerzang                                    NaN
# zrustz16                                   NaN
# zyr0n1c                                    NaN
#
# [456 rows x 82 columns]
