# %% [markdown]
# Dado que había perdido el archivo original dónde desarrollé el primer endpoint, y de manera que me quede más prolijo, cómo hice con el resto de endpoints, decidí hacer nuevamente un archivo explicando el paso a paso de cómo desarrollé el primer endpoint.

# %% [markdown]
# Así que en este archivo, voy a desarrollar la función que se me pide en el primer endpoint, que es la que se muestra a continuación:
#
# ![alt text](../img/endpoint_1.png "Title")

# %% [markdown]
# ## Importaciones necesarias para trabajar

# %%
import pandas as pd

# %%
juegos = pd.read_parquet("../Datasets/steam_games_endpoint_1.parquet")
juegos.head(2)
# Out:
#               developer  price  release_year
# 88310         Kotoshiro   4.99          2018
# 88311  Secret Level SRL   0.00          2018

# %% [markdown]
# Cómo ya había realizado este endpoint, tengo un archivo el cuál dispone toda la información necesaria para realizarlo. Veamos ahora en una lista todos los desarrolladores disponibles.

# %%
lista_desarrolladores = list(juegos["developer"].unique())
lista_desarrolladores
# Out:
# ['Kotoshiro',
#  'Secret Level SRL',
#  'Poolians.com',
#  '彼岸领域',
#  'Trickjump Games Ltd',
#  'Poppermost Productions',
#  'Stegalosaurus Game Development',
#  'Copperpick Studio',
#  'Ghulam Jewel',
#  'Apillo',
#  'Tero Lunkka',
#  'FrozenPepper',
#  'Casey Labrack',
#  'Stainless Games Ltd',
#  'Valve',
#  'dev4play',
#  'ETGgames',
#  'lalalaZero,Urbanoff',
#  'Strategy First',
#  'Outerlight Ltd.',
#  'Ultraint',
#  'TPM.CO SOFT WORKS',
#  'Wonderbox Games',
#  'Mad Unicorn Games',
#  'GlyphX Games',
#  'Introversion Software',
#  'Facepunch Studios',
#  'SimBin',
#  'Unknown Worlds Entertainment',
#  'CINEMAX, s.r.o.',
#  'Sick Puppies',
#  'Deepred',
#  'Funcom',
#  'Bugbear Entertainment',
#  'CAPCOM Co., Ltd.',
#  'FireFly Studios,Firaxis Games',
#  'Arkane Studios',
#  'Firaxis Games',
#  'PopTop',
#  'Firaxis Games,Feral Interactive (Mac)',
#  'MicroProse Software, Inc',
#  'Crystal Dynamics,Feral Interactive (Mac)',
#  'Telltale Games',
#  'id Software',
#  'Gray Matter Studios',
#  'Ritual Entertainment',
#  'Terminal Reality',
#  'Rogue Entertainment',
#  'Metamorf',
#  'Relic Entertainment',
#  '2K Boston,2K Australia',
#  'The Creative Assembly',
#  'Big Fish Games',
#  'Rockstar North',
#  'Rockstar San Diego',
#  'Remedy Entertainment',
#  'Crystal Dynamics',
#  'EA Los Angeles',
#  'Infinite Interactive',
#  'Momentum Digital Media Technologies',
#  'Gamebryo,Virtual Playground',
#  'SCS Software',
#  'Pivotal Games',
#  'Bohemia Interactive',
#  'Spellbound',
#  'Haggard Games',
#  'Eugen Systems',
#  'Frontier,Aspyr (Mac)',
#  'Epic Games, Inc.',
#  'Sanzaru Games',
#  'Ubisoft',
#  'Crytek Studios',
#  'Ubisoft Montreal',
#  'Last Day of Work',
#  'SpinTop Games',
#  'MumboJumbo',
#  'Ubisoft Bulgaria,Ubisoft Montpellier',
#  'Ubisoft Romania',
#  '1C: Maddox Games',
#  'Merscom,Babylon',
#  'BigAnt Studios',
#  'Gabriel Entertainment',
#  'Zemnott',
#  'Frogwares',
#  'Luc Bernard,SilverSphereStudios',
#  'Lesta Studio',
#  'Dialogue Design',
#  'Oddworld Inhabitants',
#  'GSC Game World',
#  'Crytek',
#  'CD PROJEKT RED',
#  'Tilted Mill Entertainment, Inc.',
#  'Red Storm Entertainment,Ubisoft Montreal',
#  "Traveller's Tales",
#  'Monte Cristo',
#  'Gearbox Software',
#  'Dark Castle Software',
#  'Techland',
#  'Nival',
#  'Blue Byte',
#  'Red Storm Entertainment',
#  'PopCap Games, Inc.',
#  '2D BOY',
#  'Egosoft',
#  'Sandstorm Productions',
#  'Shorebound Studios',
#  'Perpetual FX Creative',
#  'Rockstar New England',
#  'Meridian4',
#  'RailSimulator.com',
#  'Reppo',
#  'Dovetail Games',
#  'Volition',
#  'EA Redwood Shores',
#  'Liquid Entertainment',
#  'DICE',
#  'Hidden Path Entertainment',
#  'Monolith',
#  'Oxeye Game Studio',
#  'Inventive Dingo',
#  'Black Sea Studios Ltd',
#  'Realmforge Studios',
#  'The Creative Assembly,Feral Interactive (Mac),Feral Interactive (Linux)',
#  'Deadline Games',
#  'Frictional Games',
#  'Radon Labs',
#  'Tale of Tales',
#  'Criterion Games',
#  'Twisted Pixel Games',
#  'IonFX',
#  'Llamasoft LTD',
#  'InnoGlow,Stormregion,THQ Nordic',
#  'ArenaNet®',
#  'Reality Pump Studios',
#  'Gaijin Entertainment',
#  'ACE Team',
#  '1C Company',
#  'Sky Fallen',
#  'Irrational Games',
#  'SaintXi',
#  'Darklight Games',
#  'Radical Entertainment',
#  'Ascaron Entertainment ltd.',
#  'Bethesda Game Studios',
#  'Deck 13',
#  'NovaLogic',
#  'Mascot Entertainment',
#  'HeR Interactive',
#  'Digital Eel',
#  'Capcom',
#  'Frontier',
#  'LucasArts',
#  'Planet Moon Studios',
#  'Pandemic Studios',
#  'GFI Russia',
#  'Targem Games',
#  'Wanako Games',
#  'Sierra',
#  'Saber Interactive',
#  'Tripwire Interactive',
#  'Artech Studios',
#  'PopTop Software,BreakAway Games,Frog City Software',
#  'Sakari Indie',
#  'BioWare,Aspyr (Mac)',
#  'Hemisphere Games',
#  'Black Isle Studios',
#  '14° East',
#  'Xatrix Entertainment',
#  'iWin',
#  'Size Five Games',
#  'Unicorn Games Studio',
#  'Blue Fang',
#  'IO Interactive',
#  'Vectorpark, Inc.',
#  'All Aboard',
#  'PlayFirst',
#  'Piranha Bytes',
#  'Honeyslug',
#  'Amanita Design',
#  'Slightly Mad Studios',
#  'Runic Games',
#  'FireFly Studios',
#  'Nitro Games',
#  'Homegrown Games',
#  'Phenomic,THQ Nordic',
#  'Animation Arts',
#  'Stormregion',
#  'Konstantin Koshutin',
#  'Phenomic',
#  'Wargaming.net',
#  'Croteam',
#  'BioWare',
#  'Citeremis Inc.',
#  'Yullaby',
#  'Crystal Empire Games',
#  'Infinity Ward,Aspyr (Mac)',
#  "Traveller's Tales,Feral Interactive (Mac)",
#  'Triumph Studios,Virtual Programming',
#  'KranX Productions',
#  'Positech Games',
#  'inXile Entertainment',
#  'Defence Alliance Team',
#  'LucasArts,Aspyr Studios',
#  'Hip Soft',
#  'Spidermonk Entertainment',
#  'ClockStone Studios',
#  'Octoshark Studios',
#  'Alawar',
#  'Sandlot Games',
#  'Cateia Games',
#  'Chaos Concept',
#  'New Star Games Ltd',
#  'Paradox Interactive',
#  'The Farm 51',
#  'Awem Studio',
#  'Rebellion',
#  'TaleWorlds Entertainment',
#  'ZoopTEK',
#  'Beatnik Games',
#  'Fatshark',
#  'Rockstar North / Toronto',
#  'Other Ocean Interactive',
#  'Nemesys Games',
#  'Cold Beam Games',
#  'The Odd Gentlemen',
#  'THQ Nordic',
#  'Red Chain Games Ltd.',
#  'The Creative Assembly,Feral Interactive (Mac)',
#  'Sarbakan',
#  'Absolutist Ltd.',
#  'G5 Entertainment',
#  'Climax Studios',
#  'Muse Games',
#  'Ideas Pad',
#  'Kokakiki',
#  'SEGA',
#  'D3T Limited',
#  'Obsidian Entertainment',
#  'Team17 Software Ltd.',
#  'EA - Maxis,Aspyr (Mac)',
#  'Akella,.dat',
#  'Arcen Games, LLC',
#  'Invent4 Entertainment',
#  'Dagger Games',
#  'Rune Forge',
#  'N3V Games',
#  'Ino-Co',
#  '2K Czech,Feral Interactive (Mac)',
#  'doublesix',
#  'Playbrains',
#  'Paradox Development Studio',
#  'VStep',
#  'Team17 Digital Ltd',
#  'Muzzy Lane Software',
#  'Revolution Software Ltd',
#  'Zoë Mode',
#  'City Interactive',
#  'Terry Cavanagh',
#  'EasyGameStation',
#  'Dedication Games',
#  'exosyphen studios',
#  'Subsoap',
#  'Gaming Minds Studios',
#  'Katauri Interactive',
#  'Firaxis Games,Aspyr (Mac, Linux)',
#  'Blind Mind Studios',
#  'Krome Studios',
#  'Vigil Games',
#  'NeoCoreGames',
#  'I Sioux Game Productions B.V.',
#  'Electronic Arts',
#  'Headup Games,Silent Dreams',
#  'CAPCOM CO., LTD.',
#  'Stickmen Studios',
#  'Dmytry Lavrov',
#  'Ivy Games',
#  'Noumenon Games',
#  'Hothead Games',
#  'Klei Entertainment',
#  'Teotl Studios',
#  'Aspyr Studios',
#  'Firemint',
#  'Gaijin Games',
#  'Tomkorp Computer Solutions Inc.',
#  'Double Helix Games',
#  'Centauri Production',
#  'Altar Games',
#  'React Games',
#  'Treyarch',
#  'Sonic Boom Games',
#  'Ntreev Soft Co., Ltd.',
#  'Rockstar Games',
#  'Crystal Dynamics Inc.',
#  'Brightside Games',
#  'Extend Studio',
#  'BlueGiant Interactive',
#  'Visceral Games',
#  'Big Fish Studios',
#  'Uber Entertainment',
#  'The Sims Studio',
#  'Trinoteam',
#  'Virtual Prophecy Entertainment',
#  'Mediatonic',
#  'Cyan Worlds',
#  'Petroglyph',
#  'DTP',
#  'Stainless Games',
#  'Fakt Software',
#  'Kaos Studios,Digital Extremes',
#  'Red Redemption',
#  'Copenhagen Game Collective',
#  'Relic Entertainment,Feral Interactive (Mac/Linux)',
#  'Relic Entertainment,Feral interactive (Mac/Linux)',
#  'Trion Worlds',
#  'Stout Games',
#  'Black Lion Studios',
#  'Colossal Order Ltd.',
#  '11 bit studios',
#  'Ntronium Games',
#  'Martin Ivanov',
#  '800 North and Digital Ranch',
#  'Arrowhead Game Studios',
#  'Coffee Stain Studios',
#  '1C:InoCo',
#  'Mode 7',
#  'inner seas',
#  'Behaviour',
#  'Microids',
#  'Red Duck Inc.',
#  'Cryptic Studios',
#  'Apus Software,Three Donkeys LLC',
#  'Peter Brinson and Kurosh ValaNejad',
#  'Bacon Wrapped Games',
#  'Murudai',
#  'Totem Games',
#  'Totem games',
#  'Day 1 Studios',
#  'Bedlam Games',
#  'Giants Software',
#  'Ageod',
#  'Secret Base',
#  'YeaBoing',
#  'Mystic Box',
#  'Digitalmindsoft',
#  'Dejobaan Games, LLC',
#  'Lunar Giant',
#  'Zachtronics',
#  'Haemimont Games',
#  'Total Eclipse',
#  'Two Tribes',
#  'MinMax Games Ltd.',
#  'TimeGate Studios',
#  'Three Rings',
#  'Relic',
#  'Flying Wild Hog',
#  'Octane Games,Meridian4',
#  'PomPom',
#  'NGD Studios',
#  'Gas Powered Games',
#  'Edmund McMillen and Florian Himsl',
#  '1C-Avalon',
#  'Steel Monkeys',
#  'Games Farm,3Division',
#  'Capcom Vancouver',
#  'Days of Wonder',
#  'Double Fine Productions',
#  'Vlambeer,Croteam',
#  'b-Alive',
#  'Spellbound Studios',
#  'KTX Software',
#  'Robot Entertainment',
#  'Daybreak Game Company',
#  'Haemimont Games,Feral Interactive (Mac)',
#  "Devil's Details",
#  'Infinity Ward,Sledgehammer Games,Aspyr (Mac)',
#  'Team Bondi,Rockstar Leeds',
#  'Final Form Games',
#  'Trendy Entertainment',
#  'Cipher Prime Studios',
#  'Digital Reality',
#  'Stardock Entertainment',
#  'KrossRails,Dovetail Games',
#  'Reloaded Productions',
#  'Wadjet Eye Games',
#  'Team 6 Studios',
#  'Vicious Cycle Software, Inc.',
#  'Gaslamp Games, Inc.',
#  'Frozenbyte',
#  'ASTRO PORT',
#  'Lionhead Studios',
#  'Avalanche Studios',
#  'D3Publisher of America, Inc.',
#  'Unigine Corp.',
#  'NeocoreGames',
#  'NEOCORE GAMES',
#  'Lizsoft',
#  'Coreplay GmbH,Bigmoon Studios',
#  'RichMakeGame',
#  'Q-Games Ltd.',
#  'Owlchemy Labs',
#  'Puppygames',
#  'WXP Games, LLC',
#  'Thomson Interactive',
#  'Trashmasters',
#  'Little Green Men Games',
#  'Wild Shadow Studios',
#  'Brandon Brizzi',
#  'UBIart Montpellier,Feral Interactive (Mac)',
#  'virtualRailroads',
#  'Strange Loop Games',
#  'Cobra Mobile',
#  'Bootsnake Games',
#  'Aerosoft GmbH',
#  'Tribute Games Inc.',
#  'Most Wanted Entertainment',
#  'Trickstar Games',
#  'Nimbly Games',
#  '3 Sprockets',
#  'Strawdog Studios Ltd',
#  'Nihon Falcom',
#  'Eden Industries',
#  'PomPom Games',
#  'Trapdoor Inc.',
#  'Big Huge Games,38 Studios',
#  'Pendulo Studios',
#  'Pixelante Game Studios',
#  'Reality Pump',
#  'BUGBEAR',
#  'Longbow Games',
#  'Cyanide',
#  'David Williamson',
#  'TAO',
#  'BitSits Games',
#  'Serious Brothers',
#  'TikGames',
#  'Love Conquers All Games',
#  'Signal Studios',
#  'Coreplay GmbH',
#  'Black Market Games',
#  'Slant Six Games',
#  'Sigma Team Inc.',
#  'Rockstar Studios',
#  'Standing Stone Games, LLC',
#  'BlinkWorks Media',
#  'TT Games',
#  'Airtight Games',
#  'Nexon',
#  'Infinity Ward,Sledgehammer Games,Raven Software,Aspyr (Mac)',
#  'Zeboyd Games',
#  'Daedalic Entertainment',
#  'Ubisoft Paris,Red Storm Entertainment',
#  'Hi-Rez Studios',
#  'Larian Studios',
#  'Sakari Indie &amp; GriN',
#  'Capcom U.S.A., Inc.',
#  'Limbic Entertainment GmhH',
#  'Capcom U.S.A., Inc',
#  'Overhaul Games',
#  'Sidhe',
#  'KING Art',
#  'Misfits Attic',
#  'Tennen-sozai',
#  'Remedy Entertainment Ltd.,Mountain Sheep Inc.,Cornfox &amp; Brothers Ltd.',
#  'United Front Games',
#  'Fishlabs Entertainment GmbH',
#  'Obsidian Entertainment,Aspyr (Mac, Linux, &amp; Windows Update)',
#  'Soldak Entertainment',
#  'Big Robot Ltd',
#  'Digital Train Model',
#  'Monolith Productions, Inc.',
#  'Eyebrow Interactive',
#  'Freebird Games',
#  'Rocksteady Studios,Feral Interactive (Mac)',
#  'Aleksey Abramenko',
#  'Capybara Games',
#  'Blit Software',
#  'Ronimo Games',
#  'Limbic Entertainment GmbH',
#  'Edelweiss',
#  'Pilgway',
#  'Data Realms',
#  'Gearbox Software,Aspyr (Mac &amp; Linux)',
#  'Ubisoft - San Francisco',
#  'Ratloop Asia',
#  '2x2 Games',
#  'Lukewarm Media',
#  'Black Forest Games',
#  'Zeal Game Studio',
#  'Firaxis Games,Feral Interactive (Mac),Feral Interactive (Linux)',
#  'Dennaton Games',
#  'Running With Scissors',
#  'Codemasters Birmingham',
#  'Camel101 LLC',
#  'Ankama',
#  'Neko Entertainment',
#  'Acquire',
#  'I-deal Games',
#  'Io-Interactive A/S',
#  'IonFx',
#  'Curve Studios',
#  'Core Design',
#  'SimBin Studios AB',
#  'Wormwood Studios',
#  'NEXON Korea Corp.',
#  'Spry Fox LLC',
#  'Gaming Minds',
#  'Mind Over Matter Studios',
#  'Ascaron',
#  'DnS Development',
#  'Subatomic Studios LLC',
#  'Studio X Labs',
#  'Ironclad Games,Stardock Entertainment',
#  'Born Ready Games Ltd.',
#  'NAMCO',
#  'Ninja Theory',
#  'Hidden Path Entertainment, Inc.',
#  'Cadenza Interactive',
#  'Internal Games',
#  'Focus Home Interactive',
#  'Megadev',
#  'Jet Set Games',
#  'PV Games',
#  'Geoff Keighley',
#  'Radial Games Corp,Dejobaan Games, LLC',
#  'Colin Northway with art by Thomas Shahan',
#  'Enigma SP',
#  'Cyanide Montreal',
#  '24 Caret Games',
#  'KrossRails',
#  'Redlynx Ltd,Ubisoft  Shanghaï',
#  'Ankama Play',
#  'Carbon Games',
#  'Zeptolab UK Limited',
#  'Sean Han Tani,Joni Kittaka',
#  'Crystal Dynamics,Feral Interactive (Mac),Feral Interactive (Linux)',
#  'Shiro Games',
#  'Eric Chahi,DotEmu',
#  'Geniaware Srl',
#  'Artifice Studio',
#  'Digital Traction',
#  'Zeroscale',
#  'Minority Media Inc.',
#  'Bossa Studios',
#  'Square Enix',
#  'Old School Games',
#  'Snowbird Games',
#  'Southend',
#  'Spiders',
#  'Zero Sum Games',
#  'Adam Foster',
#  'Crocodile Entertainment',
#  'Treexy',
#  'MeshTools',
#  'Abbey Games',
#  'Digital Leisure Inc.',
#  'Point Five Projects',
#  'Degica',
#  'Enterbrain',
#  'DONTNOD Entertainment',
#  'Candygun Games',
#  'March Entertainment',
#  'Actalogic',
#  'Mousechief',
#  'Relic Entertainment,Feral Interactive (Mac),Feral Interactive (Linux)',
#  'G-TraX',
#  'Behold Studios',
#  'Iron Galaxy Studios',
#  'Irrational Games,Aspyr (Mac),Virtual Programming (Linux)',
#  'NetherRealm Studios,High Voltage Software',
#  'Gravity, Inc.',
#  'Ian Campbell',
#  'Dragonfly',
#  'Nadeo',
#  'General Arcade',
#  'Codemasters Racing,Feral Interactive (Mac)',
#  'Ludosity',
#  'Harebrained Schemes',
#  'Games Distillery s.r.o.',
#  'Zen Studios',
#  'Crafty Studios',
#  '17-BIT',
#  'MercurySteam - Climax Studios',
#  'Star Gem Inc.',
#  'Interceptor Entertainment',
#  'Pwnee Studios',
#  'Eagle Dynamics SA',
#  'Cockroach Inc.',
#  'Threaks',
#  'WayForward',
#  'Full Control Studios',
#  'Michael Todd Games',
#  'Spark Unlimited',
#  'Double Eleven,Q-Games Ltd.',
#  'Deep Silver Volition',
#  'Witch Beam',
#  'Might and Delight',
#  'Chainsawesome Games',
#  'Greenheart Games',
#  'Zombie Studios',
#  'Red Barrels',
#  'Santa Ragione',
#  'SEGA Studios Australia,Feral Interactive (Mac)',
#  '777 Studios',
#  'Runewaker',
#  'Milestone S.r.l.',
#  'ARTDINK',
#  'Impromptu Games',
#  'Phoenix Online Studios',
#  'Mediatonic,The Irregular Corporation',
#  'Belsimtek',
#  'North of Earth',
#  'FreakZone Games',
#  'Zootfly',
#  'Saibot Studios',
#  'Tate Multimedia',
#  'Mine Loader Software Co., Ltd.',
#  'Pieces Interactive',
#  '5th Cell Media',
#  'CI Games',
#  'Kot in Action Creative Artel',
#  'MagicalTimeBean',
#  'Influenzo',
#  'Galactic Cafe',
#  'Studio Bean',
#  'Topware Interactive',
#  'Nocturnal works',
#  'ClockStone',
#  'Lucky Frame',
#  'Carlsen Games',
#  'Mad Orange',
#  'InterWave Studios',
#  'Cyberdreams',
#  'sparsevector',
#  'SNK Games,Elemental Games,Katauri Interactive',
#  "Nifflas' Games",
#  'Eidos Montreal,Feral Interactive (Mac)',
#  'Monochrome, Inc',
#  'Scientifically Proven',
#  'BetaDwarf',
#  'Blue Isle Studios',
#  'Wales Interactive',
#  'Darkworks,Spiral House',
#  'Eden Games,Hydravision Entertainment',
#  'Modern Dream',
#  'Rising Star Games',
#  'Firaxis Games,Aspyr (Mac and Linux)',
#  'Undead Labs',
#  'Jackbox Games, Inc.',
#  'Infinity Ward',
#  'Firaxis',
#  'Transhuman Design',
#  'SkyBox Labs,Forgotten Empires',
#  'QCF Design',
#  'Hopoo Games, LLC',
#  'Hanako Games',
#  'The Indie Stone',
#  'Arkedo',
#  'Exor Studios',
#  'WB Games Montreal,Splash Damage',
#  'FarSight Studios',
#  'TORaIKI',
#  '2Play',
#  'Space Bullet Dynamics Corporation',
#  'Chronic Logic',
#  'Flyleap Studios Pty. Ltd.',
#  'Triple.B.Titles',
#  '8888888 LABS',
#  'PolyPusher Studios',
#  'Axis Game Factory LLC',
#  'Xtal Sword',
#  'Space Budgie',
#  'Victory Works',
#  'Renegade Kid',
#  'DotEmu',
#  'TML Studios',
#  'Storybird',
#  'Darkling Room',
#  'Simon Roth',
#  'Allgraf',
#  'Harvester Games',
#  'Awesome Games Studio',
#  'Illwinter Game Design',
#  'Clickteam',
#  'Upper Byte',
#  'Crescent Moon Games',
#  'Agharta Studio',
#  'SeeThrough Studios',
#  'WildTangent',
#  '2DArray',
#  'Dreamatrix',
#  'Netcore Games',
#  'The Collective,General Arcade',
#  'Spicyhorse',
#  'United Independent Entertainment GmbH',
#  'Exato Games Studio',
#  'Spicy Horse Games',
#  'Mindware Studios',
#  'Interdimensional Games Inc',
#  'Messhof',
#  'Hassey Enterprises, Inc.',
#  'Yakiniku Banzai',
#  'Ubisoft Sofia',
#  'Winter Wolves',
#  'Arc System Works',
#  'Rage Software',
#  'THQ Nordic,Mind Over Matter Studios',
#  'Sumom Games',
#  'Alan Edwardes',
#  'New World Interactive',
#  'Xiotex Studios Ltd',
#  'Ultra Runaway Games',
#  'Xiotex Studios',
#  'Elias Viglione,Jussi Kukkonen',
#  'Avidly Wild Games',
#  'Jason Rohrer',
#  'Mighty Rabbit Studios',
#  'BumpkinBrothers',
#  'Revultive Games',
#  'grapefrukt games',
#  'Young Horses',
#  'Dugan,Gabor,Electric Cafe',
#  'Squid In A Box Ltd',
#  'Power Up Audio',
#  'Origin8',
#  'Culture Attack Studio,Tyler Doak',
#  'Idea Factory',
#  'GTGD',
#  'Akella',
#  'Limasse Five',
#  'Milepost Simulations',
#  'Basilisk Games',
#  'Popcannibal',
#  'SNK CORPORATION,DotEmu',
#  'Doppler Interactive',
#  'Shining Rock Software LLC',
#  'Treasure',
#  'Matthew Brown',
#  'Screaming Bee',
#  'Damian Sommer,Emily Carroll',
#  'Matt Roszak',
#  'Last Dimension',
#  'MercurySteam',
#  'Nomad Games',
#  'Snowed In Studios',
#  'BANDAI NAMCO Studio Inc.',
#  'Squinkifer Productions',
#  'Squinky and the Squinkettes',
#  'Daedalic Entertainment,Irresponsible Games',
#  'Matt Thorson',
#  'Burian Media Enterprises',
#  'International Games System, Co., LTD.',
#  'Cloud 9 Studio',
#  'ComiPo! LLP',
#  'Tortuga Team',
#  'Thomas Bowker',
#  'Sherman3D',
#  'Vlambeer',
#  'bitSmith Games',
#  'Doragon Entertainment',
#  'Coilworks',
#  'Rob Howland',
#  'Crystal Shard',
#  'Pyxel Arts',
#  'ZSK Progres s.c.',
#  'Independent Arts Software',
#  'World-Loom,Nitreal',
#  'David Amador',
#  'Bongfish GmbH',
#  'Creative Assembly',
#  'Tragnarion Studios',
#  'Cranberry Production',
#  'Eversim',
#  'Artifex Mundi',
#  'Jarhead Games',
#  'Nikita',
#  'K-D Lab',
#  'CrioLand',
#  'Plastic Reality Technologies',
#  'WZOGI',
#  'Apeiron',
#  'Nemoria Entertainment',
#  'Opus',
#  'DigiFX Interactive',
#  'Vanguard Games,343 Industries',
#  'XGen Studios',
#  'Frozen Yak Entertainment',
#  'Gamebell Studio',
#  'TML-Studios',
#  'Stephane Valverde,Leslie Valverde',
#  'Niels Bauer Games',
#  'Quantized Bit',
#  'BlueLine Games',
#  'Krita Foundation',
#  'Broken Rules',
#  'Humongous Entertainment',
#  'DL Softworks',
#  'Gogii Games',
#  'Astral Byte Ltd.',
#  'Mad Otter Games',
#  'Digital Tentacle',
#  'DMD Enterprise',
#  '9heads Game Studios',
#  'Games Up',
#  'Altar Interactive',
#  'Saturn-plus,Orion',
#  'Creat Studio',
#  'DVS',
#  'Sir-Tech,Madlab Software',
#  'Slitherine Ltd.',
#  'Farsky Interactive',
#  'Black Cactus',
#  'Somi',
#  'Dirigo Games',
#  'Aartform Games',
#  'Supersonic Software',
#  'Gremlin Interactive',
#  'Eutechnyx',
#  'Hippomancer',
#  'Ubisoft Montréal',
#  'Ticonblu',
#  'souvenir circ.',
#  'Eko Software',
#  'Wingware',
#  'Abstraction Games',
#  'Croteam,Alligator Pit',
#  'GRIP Digital s.r.o.',
#  'Whole Hog Games',
#  'Windybeard',
#  'Minor Key Games',
#  "Carlo D'Apostoli Projects",
#  'Volition Inc.',
#  'Puny Human',
#  'SmiteWorks USA, LLC',
#  'Fistful of Frags Team',
#  'Steve Jarman',
#  'BitMonster, Inc.',
#  'Bedtime Digital Games',
#  'Nova Dimension,Naga Entertainment',
#  'Mimimi Productions',
#  'b-alive gmbh',
#  'Gamepires',
#  'Dancing Dragon Games',
#  'Digital Happiness',
#  'Witan Entertainment',
#  'The Behemoth',
#  'Arberth Studios',
#  'Enter Skies',
#  'Liquid Flower',
#  'Casual Brothers',
#  'Graviteam',
#  'Freegamer',
#  'Forever Entertainment S. A.',
#  'Gamatic',
#  'Alawar Entertainment',
#  'Stage Clear Studios',
#  'Hypercane Studios',
#  'Psydra Games LLC',
#  'Keybol',
#  'Supergiant Games',
#  '神奈川電子技術研究所,EXTREME',
#  'Nabi Studios',
#  'Dark Gaia Studios',
#  'RosePortal Games',
#  'Peoleo Entertainment',
#  'Evilized Productions',
#  'Rusty Moyher,Shaun Inman,Matt Grimm',
#  'Appmania/i-Free',
#  'Milkstone Studios',
#  'SkyRiver Studios',
#  'KADOKAWA GAMES / GRASSHOPPER MANUFACTURE',
#  'Étienne Périn',
#  'Myrtilus Entertainment',
#  'Koalabs',
#  'Adam Saltsman,Robin Arnott',
#  'Schulenburg Software',
#  'Graveck',
#  'QUByte Interactive',
#  'KOG',
#  'Artem Kotov',
#  'Visual Entertainment And Technologies',
#  'Endnight Games Ltd',
#  'Over The Moon',
#  'Sport1 GmbH',
#  'Arctic Anteater',
#  'Wastelands Interactive',
#  'Wild Games Studio',
#  'Uppercut Games Pty Ltd',
#  'Alawar,Mirball Games',
#  'Owl Cave',
#  'Evolutionary Games',
#  'Phosphor Games Studio',
#  'Exkee',
#  'ovos',
#  'Stage 2 Studios',
#  'Michael Todd Games,Yazar Media Group LLC',
#  'TREND, Soft Pro',
#  'SmashGames',
#  '10th Art Studio,Adventure Productions',
#  'Gunnar Games',
#  'Gojira',
#  'Anthony Case',
#  '3f Interactive',
#  'Heydeck Games',
#  'Sakura River Interactive',
#  'Unfinished Pixel',
#  'Spiders Studio',
#  'Lost Decade Games',
#  'North Side',
#  'Goldhawk Interactive',
#  'tequibo',
#  'Crazy Moo Games',
#  'Peter Cleary',
#  'Future Games,Unknown Identity',
#  'Parseh Game Studio',
#  'Choice of Games',
#  'Silesia Games Sp. z o.o.',
#  'BlackMoon Design',
#  'Cyanide Studio',
#  'Nano Games',
#  'Codemasters Racing,Feral Interactive (Mac),Feral Interactive (Linux)',
#  'MEGAFUZZ',
#  'oeFun, Inc.',
#  'rdein',
#  'SleepNinja Games',
#  'Game Dev Castle',
#  'Hailstorm Games',
#  'Wax Lyrical Games',
#  'Sideline Amusements,Gonzo Games',
#  'Crunching Koalas',
#  'Shaman Games Studio',
#  'Two Desperados',
#  'Microprose',
#  'Really Slick',
#  'Galhmac Game Studio',
#  'HandMade Game',
#  'Cryo Interactive',
#  'Laminar Research',
#  'Fixpoint Productions Ltd.',
#  'XIAOYAO,BetaSparkUK',
#  'Subvert Games',
#  'EVGA',
#  'Adam Spragg',
#  'WayForward Technologies Inc.',
#  'Lemondo Entertainment',
#  'Highcastle Studios',
#  'Nerd Monkeys®',
#  'Paul Marrable',
#  'Celestial Games',
#  'ShaunTWilliams',
#  'Hearthfire Studios',
#  'JumpCore Productions',
#  'FobTi interactive',
#  'Tom Stoffel,Puny Human',
#  'Gato Salvaje S.L.',
#  'Alan Hazelden,Harry Lee',
#  'New Reality Games',
#  'Up Multimedia',
#  'GalaxyTrail',
#  'FromSoftware, Inc',
#  'Nom Nom Games',
#  'Max Gaming Technologies, LLC',
#  'Tribe Studios',
#  'Moonshot Games',
#  'Isotope 244 LLC',
#  'Trion Worlds, Inc.',
#  'The Lordz Games Studio',
#  'Nerdook Productions',
#  'Fireproof Games',
#  'DragonSix',
#  'Elliptic Games',
#  'RedLynx, in collaboration with  Ubisoft Shanghai, Ubisoft Kiev',
#  'N94Games',
#  'Masthead Studios Ltd',
#  'Filament Games',
#  'Narrow Monolith',
#  'Sinclair Strange',
#  'Free Lives',
#  'Keen Games',
#  'Little Worlds Interactive',
#  'Night Node',
#  'Childish Things',
#  'FrameLineNetwork Kft.',
#  'gnifrebel Games UG',
#  'MADia Entertainment',
#  'Lonely Troops',
#  'Evil Twin Artworks',
#  '88mm',
#  'Ennoble Studios',
#  'A Jolly Corpse',
#  'ShaunJS',
#  'Dan  Walters,Ceri Williams',
#  'Big Pixel Studios',
#  'Duaik Entretenimento',
#  'Teyon',
#  'Freedom Factory',
#  'GamePrix',
#  'Idigicon',
#  'VR Designs',
#  'Enitvare',
#  'KOEI TECMO GAMES CO., LTD.',
#  ...]

# %% [markdown]
# Primer prototipo del endpoint

# %%
def desarrolladoras(desarrollador):
    """"
    En este primer prototipo, según la desarrolladora ingresada en la función, va a devolver los distintos años en los que publicó videojuegos.
    """
    try:
        dev_str = str(desarrollador)
        if juegos[juegos["developer"] == dev_str].empty:
            return {f"Error, la desarrolladora {dev_str} no existe.":"Intente con otra"}
        juegos_de_la_desarrolladora_ingresada = juegos[juegos["developer"] == dev_str]
        return juegos_de_la_desarrolladora_ingresada["release_year"].unique()
    except Exception as e:
        return e

# %%
desarrolladoras('Kotoshiro')
# Out:
# array([2018])

# %%
juegos[juegos["developer"] == 'Kotoshiro'] # Vemos que las salidas coindicen
# Out:
#        developer  price  release_year
# 88310  Kotoshiro   4.99          2018

# %% [markdown]
# Segundo prototipo del endpoint

# %%
def desarrolladoras(desarrollador):
    """"
    En este segundo prototipo, según la desarrolladora ingresada en la función, va a devolver los distintos años en los que publicó videojuegos, y la cantidad de los mismos.
    """
    try:
        diccionario_salida = {}
        dev_str = str(desarrollador)
        if juegos[juegos["developer"] == dev_str].empty:
            return {f"Error, la desarrolladora {dev_str} no existe.":"Intente con otra"}
        
        juegos_de_la_desarrolladora_ingresada = juegos[juegos["developer"] == dev_str]

        distintos_años_de_publicacion = list(juegos_de_la_desarrolladora_ingresada["release_year"].unique())

        distintos_años_de_publicacion = sorted(distintos_años_de_publicacion)

        for año in distintos_años_de_publicacion:
            cant_juegos_en_año_dado = len(juegos_de_la_desarrolladora_ingresada[juegos_de_la_desarrolladora_ingresada["release_year"] == año])

            diccionario_salida[año] = cant_juegos_en_año_dado

        return diccionario_salida
    except Exception as e:
        return e

# %%
desarrolladoras("Valve")
# Out:
# {1998: 1,
#  1999: 1,
#  2000: 2,
#  2001: 1,
#  2003: 1,
#  2004: 5,
#  2006: 2,
#  2007: 3,
#  2008: 1,
#  2009: 1,
#  2010: 2,
#  2011: 1,
#  2012: 1,
#  2017: 2}

# %% [markdown]
# Veamos si es cierto que en 2004 sacó 5 juegos Valve

# %%
juegos[(juegos["developer"] == "Valve") & (juegos["release_year"] == 2004)]
# Out:
#        developer  price  release_year
# 120322     Valve  19.99          2004
# 120323     Valve   9.99          2004
# 120325     Valve   4.99          2004
# 120326     Valve   9.99          2004
# 120427     Valve   9.99          2004

# %% [markdown]
# Tercer prototipo del endpoint

# %%
def desarrolladoras(desarrollador):
    """"
    En este tercer prototipo, según la desarrolladora ingresada en la función, va a devolver los distintos años en los que publicó videojuegos, la cantidad total de los mismos y la cantidad de juegos gratis.
    """
    try:
        diccionario_salida = {}
        dev_str = str(desarrollador)
        if juegos[juegos["developer"] == dev_str].empty:
            return {f"Error, la desarrolladora {dev_str} no existe.":"Intente con otra"}
        
        juegos_de_la_desarrolladora_ingresada = juegos[juegos["developer"] == dev_str]

        distintos_años_de_publicacion = list(juegos_de_la_desarrolladora_ingresada["release_year"].unique())

        distintos_años_de_publicacion = sorted(distintos_años_de_publicacion)

        for año in distintos_años_de_publicacion:
            cant_juegos_en_año_dado = len(juegos_de_la_desarrolladora_ingresada[juegos_de_la_desarrolladora_ingresada["release_year"] == año])

            cant_juegos_gratis_en_año_dado = len(juegos_de_la_desarrolladora_ingresada[(juegos_de_la_desarrolladora_ingresada["release_year"] == año) & (juegos_de_la_desarrolladora_ingresada["price"] == 0)])

            diccionario_salida[año] = cant_juegos_en_año_dado

            diccionario_salida[f"Juegos gratis {año}"] = cant_juegos_gratis_en_año_dado

            

        return diccionario_salida
    except Exception as e:
        return e

# %%
desarrolladoras("Valve")
# Out:
# {1998: 1,
#  'Juegos gratis 1998': 0,
#  1999: 1,
#  'Juegos gratis 1999': 0,
#  2000: 2,
#  'Juegos gratis 2000': 0,
#  2001: 1,
#  'Juegos gratis 2001': 0,
#  2003: 1,
#  'Juegos gratis 2003': 0,
#  2004: 5,
#  'Juegos gratis 2004': 0,
#  2006: 2,
#  'Juegos gratis 2006': 0,
#  2007: 3,
#  'Juegos gratis 2007': 1,
#  2008: 1,
#  'Juegos gratis 2008': 0,
#  2009: 1,
#  'Juegos gratis 2009': 0,
#  2010: 2,
#  'Juegos gratis 2010': 1,
#  2011: 1,
#  'Juegos gratis 2011': 0,
#  2012: 1,
#  'Juegos gratis 2012': 0,
#  2017: 2,
#  'Juegos gratis 2017': 0}

# %% [markdown]
# Cuarto prototipo del endpoint

# %%
def desarrolladoras(desarrollador):
    """"
    En este cuarto prototipo, según la desarrolladora ingresada en la función, va a devolver los distintos años en los que publicó videojuegos, la cantidad total de los mismos y el porcentaje de juegos gratuitos.
    """
    try:
        diccionario_salida = {}
        dev_str = str(desarrollador)
        if juegos[juegos["developer"] == dev_str].empty:
            return {f"Error, la desarrolladora {dev_str} no existe.":"Intente con otra"}
        
        juegos_de_la_desarrolladora_ingresada = juegos[juegos["developer"] == dev_str]

        distintos_años_de_publicacion = list(juegos_de_la_desarrolladora_ingresada["release_year"].unique())

        distintos_años_de_publicacion = sorted(distintos_años_de_publicacion)

        for año in distintos_años_de_publicacion:
            cant_juegos_en_año_dado = len(juegos_de_la_desarrolladora_ingresada[juegos_de_la_desarrolladora_ingresada["release_year"] == año])

            cant_juegos_gratis_en_año_dado = len(juegos_de_la_desarrolladora_ingresada[(juegos_de_la_desarrolladora_ingresada["release_year"] == año) & (juegos_de_la_desarrolladora_ingresada["price"] == 0)])

            porcentaje_juegos_gratuitos_en_año_dado = round((cant_juegos_gratis_en_año_dado * 100) / cant_juegos_en_año_dado, 2)

            diccionario_salida[f"Año {año}"] = f"Cantidad de juegos {cant_juegos_en_año_dado}"

            diccionario_salida[f"Porcentaje juegos gratis en {año}"] = f"{porcentaje_juegos_gratuitos_en_año_dado}%"

            

        return diccionario_salida
    except Exception as e:
        return e

# %%
desarrolladoras("Valve")
# Out:
# {'Año 1998': 'Cantidad de juegos 1',
#  'Porcentaje juegos gratis en 1998': '0.0%',
#  'Año 1999': 'Cantidad de juegos 1',
#  'Porcentaje juegos gratis en 1999': '0.0%',
#  'Año 2000': 'Cantidad de juegos 2',
#  'Porcentaje juegos gratis en 2000': '0.0%',
#  'Año 2001': 'Cantidad de juegos 1',
#  'Porcentaje juegos gratis en 2001': '0.0%',
#  'Año 2003': 'Cantidad de juegos 1',
#  'Porcentaje juegos gratis en 2003': '0.0%',
#  'Año 2004': 'Cantidad de juegos 5',
#  'Porcentaje juegos gratis en 2004': '0.0%',
#  'Año 2006': 'Cantidad de juegos 2',
#  'Porcentaje juegos gratis en 2006': '0.0%',
#  'Año 2007': 'Cantidad de juegos 3',
#  'Porcentaje juegos gratis en 2007': '33.33%',
#  'Año 2008': 'Cantidad de juegos 1',
#  'Porcentaje juegos gratis en 2008': '0.0%',
#  'Año 2009': 'Cantidad de juegos 1',
#  'Porcentaje juegos gratis en 2009': '0.0%',
#  'Año 2010': 'Cantidad de juegos 2',
#  'Porcentaje juegos gratis en 2010': '50.0%',
#  'Año 2011': 'Cantidad de juegos 1',
#  'Porcentaje juegos gratis en 2011': '0.0%',
#  'Año 2012': 'Cantidad de juegos 1',
#  'Porcentaje juegos gratis en 2012': '0.0%',
#  'Año 2017': 'Cantidad de juegos 2',
#  'Porcentaje juegos gratis en 2017': '0.0%'}

# %% [markdown]
# Bueno, con ello ya tengo prácticamente todo lo que se me pide en el primer endpoint, pero me gustaría modificar la salida de manera que me quede:
#
# {Año x : {Cantidad de juegos : y, Porcentaje de juegos gratuitos : z%}}
#
# a ello voy

# %% [markdown]
# Quinto prototipo del endpoint

# %%
def desarrolladoras(desarrollador):
    """"
    En este quinto prototipo, según la desarrolladora ingresada en la función, va a devolver de forma mucho más prolija, los distintos años en los que publicó videojuegos, la cantidad total de los mismos y el porcentaje de juegos gratuitos.
    """
    try:
        diccionario_salida = {}
        dev_str = str(desarrollador)
        if juegos[juegos["developer"] == dev_str].empty:
            return {f"Error, la desarrolladora {dev_str} no existe.":"Intente con otra"}
        
        juegos_de_la_desarrolladora_ingresada = juegos[juegos["developer"] == dev_str]

        distintos_años_de_publicacion = list(juegos_de_la_desarrolladora_ingresada["release_year"].unique())

        distintos_años_de_publicacion = sorted(distintos_años_de_publicacion)

        for año in distintos_años_de_publicacion:

            diccionario_interno = {}

            cant_juegos_en_año_dado = len(juegos_de_la_desarrolladora_ingresada[juegos_de_la_desarrolladora_ingresada["release_year"] == año])

            diccionario_interno["Cantidad de juegos"] = cant_juegos_en_año_dado

            cant_juegos_gratis_en_año_dado = len(juegos_de_la_desarrolladora_ingresada[(juegos_de_la_desarrolladora_ingresada["release_year"] == año) & (juegos_de_la_desarrolladora_ingresada["price"] == 0)])

            porcentaje_juegos_gratuitos_en_año_dado = round((cant_juegos_gratis_en_año_dado * 100) / cant_juegos_en_año_dado, 2)

            diccionario_interno["Porcentaje de juegos gratuitos"] = f"{porcentaje_juegos_gratuitos_en_año_dado}%"

            diccionario_salida[f"Año {año}"] = diccionario_interno


        return diccionario_salida
    except Exception as e:
        return e

# %%
desarrolladoras("Valve")
# Out:
# {'Año 1998': {'Cantidad de juegos': 1,
#   'Porcentaje de juegos gratuitos': '0.0%'},
#  'Año 1999': {'Cantidad de juegos': 1,
#   'Porcentaje de juegos gratuitos': '0.0%'},
#  'Año 2000': {'Cantidad de juegos': 2,
#   'Porcentaje de juegos gratuitos': '0.0%'},
#  'Año 2001': {'Cantidad de juegos': 1,
#   'Porcentaje de juegos gratuitos': '0.0%'},
#  'Año 2003': {'Cantidad de juegos': 1,
#   'Porcentaje de juegos gratuitos': '0.0%'},
#  'Año 2004': {'Cantidad de juegos': 5,
#   'Porcentaje de juegos gratuitos': '0.0%'},
#  'Año 2006': {'Cantidad de juegos': 2,
#   'Porcentaje de juegos gratuitos': '0.0%'},
#  'Año 2007': {'Cantidad de juegos': 3,
#   'Porcentaje de juegos gratuitos': '33.33%'},
#  'Año 2008': {'Cantidad de juegos': 1,
#   'Porcentaje de juegos gratuitos': '0.0%'},
#  'Año 2009': {'Cantidad de juegos': 1,
#   'Porcentaje de juegos gratuitos': '0.0%'},
#  'Año 2010': {'Cantidad de juegos': 2,
#   'Porcentaje de juegos gratuitos': '50.0%'},
#  'Año 2011': {'Cantidad de juegos': 1,
#   'Porcentaje de juegos gratuitos': '0.0%'},
#  'Año 2012': {'Cantidad de juegos': 1,
#   'Porcentaje de juegos gratuitos': '0.0%'},
#  'Año 2017': {'Cantidad de juegos': 2,
#   'Porcentaje de juegos gratuitos': '0.0%'}}
